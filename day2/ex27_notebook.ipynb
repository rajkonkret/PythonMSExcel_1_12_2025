# %% [markdown]
# # Początek
# ## mniejsze
# ### jescze mniejsze
#
# **pogrubione**
# zwykły tekst\
# nowa linia

# %%
print("Radek")
# Out:
# Radek

# %%
import pandas as pd

# %%
df = pd.read_excel("excel_with_multiple_sheets.xlsx", sheet_name=2)
print("The dataframe is:")
print(df)
# Out:
# The dataframe is:
#     Name  Marks
# 0  Adiya    179
# 1  Samen    181
# 2  Darek    170
# 3   Jhon    167

# %%
a = "Radek"

# %%
print(a)
# Out:
# Radek

# %%
 a
# Out:
# 'Radek'

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------  8.1/8.3 MB 54.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 42.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 75.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---------------------------------------- 7.1/7.1 MB 78.9 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = [1, 2, 3, 4, 5]
y = [2, 5, 7, 9, 11]

# %%
plt.plot(x, y)
plt.show() # potrzebne w pythine
